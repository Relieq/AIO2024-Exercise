# %% [markdown]
# # 1. Tải bộ dữ liệu

# %%
# !gdown -q 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu

# %% [markdown]
# # 2. Import các thư viện cần thiết

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 3. Cài đặt giá trị ngẫu nhiên cố định

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)
    torch.cuda.manual_seed_all(random_state)

# %% [markdown]
# # 4. Cài đặt thiết bị tính toán

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # 5. Đọc bộ dữ liệu

# %%
dataset_path = '/content/Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %% [markdown]
# # 6. Tiền xử lí bộ dữ liệu

# %%
X = dataset.drop('MPG', axis=1).values
y = dataset['MPG'].values

# %%
val_size = .2
test_size = .125
is_shuffle = True

# Do bên kia làm thế chứ không thực sự muốn đảo lại thứ tự cho hợp logic
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_size, shuffle=is_shuffle,
                                                  random_state=random_state)
X_val, X_test, y_val, y_test = train_test_split(X_val, y_val, test_size=test_size, shuffle=is_shuffle,
                                                random_state=random_state)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# # 7. Xây dựng DataLoader

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
test_dataset = CustomDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # 8. Xây dựng mạng MLP

# %%
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, hidden_dim)
        self.output = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1) # Loại bỏ các chiều có kích thước bằng 1, kiểu [[1, 2, 3]] sẽ thành [1, 2, 3]

# %%
input_dims = X.shape[1]
hidden_dims = 64
output_dims = 1

model = MLP(input_dims, hidden_dims, output_dims).to(device)

# %% [markdown]
# # 9. Khai báo hàm loss và optimizer

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# # 10. Xây dựng hàm tính điểm R2

# %%
def r_squared(y_pred, y_true):
    y_true = torch.tensor(y_true, dtype=torch.float32).to(device)
    y_pred = torch.tensor(y_pred, dtype=torch.float32).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %% [markdown]
# # 11. Huấn luyện mô hình

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

for epoch in range(epochs):
    train_loss = 0
    train_target = []
    train_predict = []
    val_loss = 0
    val_target = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        output = model(X_samples)
        train_predict += output.tolist()
        train_target += y_samples.tolist()
        loss = criterion(output, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_predict, train_target))

    model.eval()
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            output = model(X_samples)
            val_predict += output.tolist()
            val_target += y_samples.tolist()
            loss = criterion(output, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_predict, val_target))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 370.184	Validation loss: 366.810
#
# EPOCH 2:	Training loss: 108.023	Validation loss: 23.386
#
# EPOCH 3:	Training loss: 117.756	Validation loss: 8.579
#
# EPOCH 4:	Training loss: 15.851	Validation loss: 90.674
#
# EPOCH 5:	Training loss: 21.286	Validation loss: 43.918
#
# EPOCH 6:	Training loss: 26.367	Validation loss: 27.560
#
# EPOCH 7:	Training loss: 22.069	Validation loss: 77.718
#
# EPOCH 8:	Training loss: 19.093	Validation loss: 19.518
#
# EPOCH 9:	Training loss: 18.030	Validation loss: 4.561
#
# EPOCH 10:	Training loss: 13.548	Validation loss: 4.855
#
# EPOCH 11:	Training loss: 14.068	Validation loss: 4.925
#
# EPOCH 12:	Training loss: 9.779	Validation loss: 16.828
#
# EPOCH 13:	Training loss: 15.061	Validation loss: 9.306
#
# EPOCH 14:	Training loss: 16.595	Validation loss: 4.251
#
# EPOCH 15:	Training loss: 7.914	Validation loss: 5.058
#
# EPOCH 16:	Training loss: 12.166	Validation loss: 3.816
#
# EPOCH 17:	Training loss: 8.639	Validation loss: 6.018
#
# EPOCH 18:	Training loss: 10.666	Validation loss: 17.986
#
# EPOCH 19:	Training loss: 11.956	Validation loss: 4.142
#
# EPOCH 20:	Training loss: 9.267	Validation loss: 5.433
#
# EPOCH 21:	Training loss: 9.031	Validation loss: 38.556
#
# EPOCH 22:	Training loss: 10.448	Validation loss: 5.456
#
# EPOCH 23:	Training loss: 7.728	Validation loss: 15.918
#
# EPOCH 24:	Training loss: 8.424	Validation loss: 3.542
#
# EPOCH 25:	Training loss: 8.500	Validation loss: 14.293
#
# EPOCH 26:	Training loss: 6.721	Validation loss: 5.288
#
# EPOCH 27:	Training loss: 8.349	Validation loss: 3.590
#
# EPOCH 28:	Training loss: 6.623	Validation loss: 3.320
#
# EPOCH 29:	Training loss: 6.566	Validation loss: 4.586
#
# EPOCH 30:	Training loss: 7.471	Validation loss: 4.704
#
# EPOCH 31:	Training loss: 6.919	Validation loss: 3.981
#
# EPOCH 32:	Training loss: 6.236	Validation loss: 4.806
#
# EPOCH 33:	Training loss: 6.070	Validation loss: 31.048
#
# EPOCH 34:	Training loss: 14.092	Validation loss: 5.197
#
# EPOCH 35:	Training loss: 10.457	Validation loss: 4.277
#
# EPOCH 36:	Training loss: 7.750	Validation loss: 3.789
#
# EPOCH 37:	Training loss: 8.855	Validation loss: 5.279
#
# EPOCH 38:	Training loss: 8.302	Validation loss: 11.317
#
# EPOCH 39:	Training loss: 6.615	Validation loss: 3.884
#
# EPOCH 40:	Training loss: 5.826	Validation loss: 4.781
#
# EPOCH 41:	Training loss: 7.385	Validation loss: 3.753
#
# EPOCH 42:	Training loss: 9.019	Validation loss: 12.529
#
# EPOCH 43:	Training loss: 11.064	Validation loss: 56.573
#
# EPOCH 44:	Training loss: 14.366	Validation loss: 17.030
#
# EPOCH 45:	Training loss: 13.464	Validation loss: 3.968
#
# EPOCH 46:	Training loss: 7.725	Validation loss: 3.889
#
# EPOCH 47:	Training loss: 6.805	Validation loss: 3.240
#
# EPOCH 48:	Training loss: 6.421	Validation loss: 4.988
#
# EPOCH 49:	Training loss: 6.413	Validation loss: 6.110
#
# EPOCH 50:	Training loss: 9.556	Validation loss: 6.172
#
# EPOCH 51:	Training loss: 9.625	Validation loss: 3.603
#
# EPOCH 52:	Training loss: 7.087	Validation loss: 13.683
#
# EPOCH 53:	Training loss: 7.768	Validation loss: 3.956
#
# EPOCH 54:	Training loss: 8.982	Validation loss: 4.522
#
# EPOCH 55:	Training loss: 5.956	Validation loss: 4.672
#
# EPOCH 56:	Training loss: 5.637	Validation loss: 4.269
#
# EPOCH 57:	Training loss: 6.191	Validation loss: 3.319
#
# EPOCH 58:	Training loss: 6.688	Validation loss: 3.812
#
# EPOCH 59:	Training loss: 6.786	Validation loss: 3.804
#
# EPOCH 60:	Training loss: 6.224	Validation loss: 5.162
#
# EPOCH 61:	Training loss: 6.932	Validation loss: 4.942
#
# EPOCH 62:	Training loss: 6.357	Validation loss: 4.024
#
# EPOCH 63:	Training loss: 5.494	Validation loss: 3.914
#
# EPOCH 64:	Training loss: 5.635	Validation loss: 3.941
#
# EPOCH 65:	Training loss: 9.656	Validation loss: 6.709
#
# EPOCH 66:	Training loss: 6.503	Validation loss: 4.756
#
# EPOCH 67:	Training loss: 5.861	Validation loss: 3.629
#
# EPOCH 68:	Training loss: 6.360	Validation loss: 6.354
#
# EPOCH 69:	Training loss: 6.343	Validation loss: 9.163
#
# EPOCH 70:	Training loss: 6.290	Validation loss: 5.047
#
# EPOCH 71:	Training loss: 5.776	Validation loss: 5.197
#
# EPOCH 72:	Training loss: 5.533	Validation loss: 7.170
#
# EPOCH 73:	Training loss: 6.361	Validation loss: 3.823
#
# EPOCH 74:	Training loss: 6.887	Validation loss: 5.359
#
# EPOCH 75:	Training loss: 6.471	Validation loss: 9.359
#
# EPOCH 76:	Training loss: 8.573	Validation loss: 16.170
#
# EPOCH 77:	Training loss: 6.854	Validation loss: 10.310
#
# EPOCH 78:	Training loss: 5.232	Validation loss: 3.916
#
# EPOCH 79:	Training loss: 7.816	Validation loss: 5.101
#
# EPOCH 80:	Training loss: 7.361	Validation loss: 20.783
#
# EPOCH 81:	Training loss: 8.096	Validation loss: 4.257
#
# EPOCH 82:	Training loss: 6.964	Validation loss: 3.753
#
# EPOCH 83:	Training loss: 5.854	Validation loss: 6.061
#
# EPOCH 84:	Training loss: 7.335	Validation loss: 4.454
#
# EPOCH 85:	Training loss: 6.836	Validation loss: 7.226
#
# EPOCH 86:	Training loss: 6.443	Validation loss: 5.796
#
# EPOCH 87:	Training loss: 5.804	Validation loss: 3.747
#
# EPOCH 88:	Training loss: 8.158	Validation loss: 4.517
#
# EPOCH 89:	Training loss: 5.876	Validation loss: 5.396
#
# EPOCH 90:	Training loss: 6.464	Validation loss: 4.784
#
# EPOCH 91:	Training loss: 6.917	Validation loss: 6.223
#
# EPOCH 92:	Training loss: 5.305	Validation loss: 4.925
#
# EPOCH 93:	Training loss: 5.889	Validation loss: 7.674
#
# EPOCH 94:	Training loss: 6.343	Validation loss: 6.865
#
# EPOCH 95:	Training loss: 5.630	Validation loss: 5.765
#
# EPOCH 96:	Training loss: 6.551	Validation loss: 12.149
#
# EPOCH 97:	Training loss: 7.764	Validation loss: 5.241
#
# EPOCH 98:	Training loss: 5.956	Validation loss: 6.669
#
# EPOCH 99:	Training loss: 5.011	Validation loss: 8.624
#
# EPOCH 100:	Training loss: 5.632	Validation loss: 3.793

# %% [markdown]
# # 12. Đánh giá mô hình

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_test.to(device))
    test_set_r2 = r_squared(y_test, y_hat)
    print('Evaluation on test set:')
    print(f'R2 score: {test_set_r2}')
# Out:
# Evaluation on test set:
# R2 score: 0.78011554479599
# <ipython-input-14-baa6280489f1>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true = torch.tensor(y_true, dtype=torch.float32).to(device)
# <ipython-input-14-baa6280489f1>:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_pred = torch.tensor(y_pred, dtype=torch.float32).to(device)
